# %% [markdown]
# # Imports

# %%
# Import libraries
import pandas as pd
import numpy as np
from pathlib import Path

# %%
# Set data paths
PROJECT_ROOT = Path().resolve().parent
DATA_RAW = PROJECT_ROOT / "data" / "raw"

# %%
# Import datasets
zhvi_path = DATA_RAW / "County_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv"
df = pd.read_csv(zhvi_path)

# %% [markdown]
# # Review Dataframe

# %%
df.head()
# Out:
#    RegionID  SizeRank          RegionName RegionType StateName State  \
# 0      3101         0  Los Angeles County     county        CA    CA
# 1       139         1         Cook County     county        IL    IL
# 2      1090         2       Harris County     county        TX    TX
# 3      2402         3     Maricopa County     county        AZ    AZ
# 4      2841         4    San Diego County     county        CA    CA
#
#                                   Metro  StateCodeFIPS  MunicipalCodeFIPS  \
# 0    Los Angeles-Long Beach-Anaheim, CA              6                 37
# 1    Chicago-Naperville-Elgin, IL-IN-WI             17                 31
# 2  Houston-The Woodlands-Sugar Land, TX             48                201
# 3             Phoenix-Mesa-Chandler, AZ              4                 13
# 4    San Diego-Chula Vista-Carlsbad, CA              6                 73
#
#       2000-01-31  ...     2025-04-30     2025-05-31     2025-06-30  \
# 0  207378.139086  ...  867632.681133  862661.764204  858520.151316
# 1  145233.876893  ...  305530.329774  305517.804006  305528.696370
# 2  110482.270951  ...  281842.195255  280848.873550  279813.187274
# 3  144511.068258  ...  463419.137829  461388.955195  459510.628710
# 4  210703.817869  ...  919396.983969  914664.101695  909523.902460
#
#       2025-07-31     2025-08-31     2025-09-30     2025-10-31     2025-11-30  \
# 0  856622.139882  856586.892712  858660.997572  861457.187977  864644.681242
# 1  306245.743513  307136.890573  308465.410472  309734.510842  311204.053706
# 2  278960.376724  278213.144299  277666.065467  277216.424846  276987.919005
# 3  457492.403994  455839.626275  454769.654599  454342.106269  454563.676008
# 4  905227.788816  901869.469439  900047.881347  900016.924724  900997.603262
#
#       2025-12-31     2026-01-31
# 0  868121.048715  869779.688397
# 1  312760.209619  314157.004441
# 2  277033.758614  276889.152202
# 3  455339.961570  456184.043231
# 4  903114.130925  904312.219896
#
# [5 rows x 322 columns]

# %%
df.shape
# Out:
# (3073, 322)

# %% [markdown]
# ## Check for completeness and duplicates

# %%
df["RegionType"].value_counts(dropna=False)
# Out:
# RegionType
# county    3073
# Name: count, dtype: int64

# %%
df[["State", "StateName"]].drop_duplicates()
# Out:
#     State StateName
# 0      CA        CA
# 1      IL        IL
# 2      TX        TX
# 3      AZ        AZ
# 6      NY        NY
# 7      FL        FL
# 11     WA        WA
# 12     NV        NV
# 18     MI        MI
# 21     MA        MA
# 22     PA        PA
# 30     OH        OH
# 32     MN        MN
# 36     UT        UT
# 38     VA        VA
# 39     NC        NC
# 41     MD        MD
# 42     GA        GA
# 45     HI        HI
# 47     MO        MO
# 50     IN        IN
# 53     CT        CT
# 54     NJ        NJ
# 57     WI        WI
# 59     TN        TN
# 77     OR        OR
# 81     OK        OK
# 82     KY        KY
# 89     CO        CO
# 98     DC        DC
# 99     NM        NM
# 100    AL        AL
# 102    RI        RI
# 110    KS        KS
# 117    NE        NE
# 121    DE        DE
# 137    SC        SC
# 145    IA        IA
# 146    ID        ID
# 156    LA        LA
# 167    NH        NH
# 179    AR        AR
# 231    ME        ME
# 238    AK        AK
# 295    MS        MS
# 344    SD        SD
# 362    ND        ND
# 365    WV        WV
# 398    VT        VT
# 405    MT        MT
# 600    WY        WY

# %% [markdown]
# # Filter to Florida counties

# %%
df_fl=df[df["State"] == "FL"].copy()

# %%
df_fl.shape
# Out:
# (67, 322)

# %%
df_fl["RegionName"].head()
# Out:
# 7       Miami-Dade County
# 17         Broward County
# 25      Palm Beach County
# 27    Hillsborough County
# 28          Orange County
# Name: RegionName, dtype: object

# %% [markdown]
# # Identify the date columns

# %%
# Reference column names
df_fl.columns
# Out:
# Index(['RegionID', 'SizeRank', 'RegionName', 'RegionType', 'StateName',
#        'State', 'Metro', 'StateCodeFIPS', 'MunicipalCodeFIPS', '2000-01-31',
#        ...
#        '2025-04-30', '2025-05-31', '2025-06-30', '2025-07-31', '2025-08-31',
#        '2025-09-30', '2025-10-31', '2025-11-30', '2025-12-31', '2026-01-31'],
#       dtype='object', length=322)

# %%
# Get all non-date columns 
id_cols = ["RegionID", "SizeRank", "RegionName", "RegionType", "StateName", "State", "Metro", "StateCodeFIPS", "MunicipalCodeFIPS"]

# %%
# Get all other columns (date columns)
date_cols = []

for c in df_fl.columns:
    if c not in id_cols:
        date_cols.append(c)

# %% [markdown]
# # Reshape wide format to long format

# %%
# We want dates in rows so that time becomes a variable

# %%
# melt takes many date columns and stacks them vertically
zhvi_long = df_fl.melt(
    id_vars=id_cols,
    value_vars=date_cols,
    var_name="date",
    value_name="zhvi"
)

# %% [markdown]
# # Convert date column from string to datetime object

# %%
zhvi_long["date"] = pd.to_datetime(zhvi_long["date"])

# %%
# Verify change
zhvi_long.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20971 entries, 0 to 20970
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   RegionID           20971 non-null  int64
#  1   SizeRank           20971 non-null  int64
#  2   RegionName         20971 non-null  object
#  3   RegionType         20971 non-null  object
#  4   StateName          20971 non-null  object
#  5   State              20971 non-null  object
#  6   Metro              15963 non-null  object
#  7   StateCodeFIPS      20971 non-null  int64
#  8   MunicipalCodeFIPS  20971 non-null  int64
#  9   date               20971 non-null  datetime64[ns]
#  10  zhvi               19709 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(5)
# memory usage: 1.8+ MB

# %% [markdown]
# # Sort Data

# %%
zhvi_long = zhvi_long.sort_values(["RegionName", "date"])

# %%
zhvi_long.head()
# Out:
#      RegionID  SizeRank      RegionName RegionType StateName State  \
# 22       1509       251  Alachua County     county        FL    FL
# 89       1509       251  Alachua County     county        FL    FL
# 156      1509       251  Alachua County     county        FL    FL
# 223      1509       251  Alachua County     county        FL    FL
# 290      1509       251  Alachua County     county        FL    FL
#
#                Metro  StateCodeFIPS  MunicipalCodeFIPS       date  \
# 22   Gainesville, FL             12                  1 2000-01-31
# 89   Gainesville, FL             12                  1 2000-02-29
# 156  Gainesville, FL             12                  1 2000-03-31
# 223  Gainesville, FL             12                  1 2000-04-30
# 290  Gainesville, FL             12                  1 2000-05-31
#
#               zhvi
# 22   105280.379237
# 89   105518.438659
# 156  105833.697224
# 223  106220.608362
# 290  106499.654540

# %% [markdown]
# # Create a year column (for Census dataset merge)

# %%
zhvi_long["year"] = zhvi_long["date"].dt.year

# %%
zhvi_long.head(20)
# Out:
#       RegionID  SizeRank      RegionName RegionType StateName State  \
# 22        1509       251  Alachua County     county        FL    FL
# 89        1509       251  Alachua County     county        FL    FL
# 156       1509       251  Alachua County     county        FL    FL
# 223       1509       251  Alachua County     county        FL    FL
# 290       1509       251  Alachua County     county        FL    FL
# 357       1509       251  Alachua County     county        FL    FL
# 424       1509       251  Alachua County     county        FL    FL
# 491       1509       251  Alachua County     county        FL    FL
# 558       1509       251  Alachua County     county        FL    FL
# 625       1509       251  Alachua County     county        FL    FL
# 692       1509       251  Alachua County     county        FL    FL
# 759       1509       251  Alachua County     county        FL    FL
# 826       1509       251  Alachua County     county        FL    FL
# 893       1509       251  Alachua County     county        FL    FL
# 960       1509       251  Alachua County     county        FL    FL
# 1027      1509       251  Alachua County     county        FL    FL
# 1094      1509       251  Alachua County     county        FL    FL
# 1161      1509       251  Alachua County     county        FL    FL
# 1228      1509       251  Alachua County     county        FL    FL
# 1295      1509       251  Alachua County     county        FL    FL
#
#                 Metro  StateCodeFIPS  MunicipalCodeFIPS       date  \
# 22    Gainesville, FL             12                  1 2000-01-31
# 89    Gainesville, FL             12                  1 2000-02-29
# 156   Gainesville, FL             12                  1 2000-03-31
# 223   Gainesville, FL             12                  1 2000-04-30
# 290   Gainesville, FL             12                  1 2000-05-31
# 357   Gainesville, FL             12                  1 2000-06-30
# 424   Gainesville, FL             12                  1 2000-07-31
# 491   Gainesville, FL             12                  1 2000-08-31
# 558   Gainesville, FL             12                  1 2000-09-30
# 625   Gainesville, FL             12                  1 2000-10-31
# 692   Gainesville, FL             12                  1 2000-11-30
# 759   Gainesville, FL             12                  1 2000-12-31
# 826   Gainesville, FL             12                  1 2001-01-31
# 893   Gainesville, FL             12                  1 2001-02-28
# 960   Gainesville, FL             12                  1 2001-03-31
# 1027  Gainesville, FL             12                  1 2001-04-30
# 1094  Gainesville, FL             12                  1 2001-05-31
# 1161  Gainesville, FL             12                  1 2001-06-30
# 1228  Gainesville, FL             12                  1 2001-07-31
# 1295  Gainesville, FL             12                  1 2001-08-31
#
#                zhvi  year
# 22    105280.379237  2000
# 89    105518.438659  2000
# 156   105833.697224  2000
# 223   106220.608362  2000
# 290   106499.654540  2000
# 357   106592.765411  2000
# 424   106842.281871  2000
# 491   107241.186029  2000
# 558   107775.546358  2000
# 625   108326.137802  2000
# 692   108792.552605  2000
# 759   109198.208513  2000
# 826   109560.122724  2001
# 893   110009.763073  2001
# 960   110531.183739  2001
# 1027  111171.868719  2001
# 1094  111788.906849  2001
# 1161  112410.817820  2001
# 1228  113053.587515  2001
# 1295  113731.119848  2001

# %% [markdown]
# # Filter to 2020+

# %%
zhvi_recent = zhvi_long[zhvi_long["year"] >= 2020].copy()

# %% [markdown]
# # Check for duplicates and missing values

# %%
zhvi_recent["zhvi"].isna().sum()
# Out:
# np.int64(0)

# %%
zhvi_recent.duplicated(subset=["RegionName", "date"]).sum()
# Out:
# np.int64(0)

# %%
# Sanity check

# %%
zhvi_recent
# Out:
#        RegionID  SizeRank         RegionName RegionType StateName State  \
# 16102      1509       251     Alachua County     county        FL    FL
# 16169      1509       251     Alachua County     county        FL    FL
# 16236      1509       251     Alachua County     county        FL    FL
# 16303      1509       251     Alachua County     county        FL    FL
# 16370      1509       251     Alachua County     county        FL    FL
# ...         ...       ...                ...        ...       ...   ...
# 20688      3050      1653  Washington County     county        FL    FL
# 20755      3050      1653  Washington County     county        FL    FL
# 20822      3050      1653  Washington County     county        FL    FL
# 20889      3050      1653  Washington County     county        FL    FL
# 20956      3050      1653  Washington County     county        FL    FL
#
#                  Metro  StateCodeFIPS  MunicipalCodeFIPS       date  \
# 16102  Gainesville, FL             12                  1 2020-01-31
# 16169  Gainesville, FL             12                  1 2020-02-29
# 16236  Gainesville, FL             12                  1 2020-03-31
# 16303  Gainesville, FL             12                  1 2020-04-30
# 16370  Gainesville, FL             12                  1 2020-05-31
# ...                ...            ...                ...        ...
# 20688              NaN             12                133 2025-09-30
# 20755              NaN             12                133 2025-10-31
# 20822              NaN             12                133 2025-11-30
# 20889              NaN             12                133 2025-12-31
# 20956              NaN             12                133 2026-01-31
#
#                 zhvi  year
# 16102  205945.224353  2020
# 16169  207639.389278  2020
# 16236  209186.222049  2020
# 16303  210416.781373  2020
# 16370  211241.441421  2020
# ...              ...   ...
# 20688  212851.950315  2025
# 20755  211852.240228  2025
# 20822  210730.593741  2025
# 20889  208866.861365  2025
# 20956  208173.112982  2026
#
# [4891 rows x 12 columns]

# %% [markdown]
# # Exports

# %%
zhvi_recent.to_csv("../data/processed/zhvi_fl_long.csv", index=False)
